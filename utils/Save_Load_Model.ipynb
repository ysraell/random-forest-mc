# %% [markdown]
# # Save and Load Model
#
# - Author: Israel Oliveira [\[e-mail\]](mailto:'Israel%20Oliveira%20'<prof.israel@gmail.com>)

# %%
#!pip3 install -U random-forest-mc

# %%
# %load_ext watermark

# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd

import sys
sys.path.append('../src/random_forest_mc')
from model import *

# %%
# from tqdm import notebook as tqdm

from glob import glob

# import matplotlib.pyplot as plt
# %matplotlib inline
# from matplotlib import rcParams
# from cycler import cycler

# rcParams['figure.figsize'] = 12, 8 # 18, 5
# rcParams['axes.spines.top'] = False
# rcParams['axes.spines.right'] = False
# rcParams['axes.grid'] = True
# rcParams['axes.prop_cycle'] = cycler(color=['#365977'])
# rcParams['lines.linewidth'] = 2.5

# import seaborn as sns
# sns.set_theme()

# pd.set_option("max_columns", None)
# pd.set_option("max_rows", None)
# pd.set_option('display.max_colwidth', None)

from IPython.display import Markdown, display
def md(arg):
    display(Markdown(arg))

# from pandas_profiling import ProfileReport
# #report = ProfileReport(#DataFrame here#, minimal=True)
# #report.to

# import pyarrow.parquet as pq
# #df = pq.ParquetDataset(path_to_folder_with_parquets, filesystem=None).read_pandas().to_pandas()

# import functools
# import operator
# def flat(a):
#     return functools.reduce(operator.iconcat, a, [])


######### LoadDicts

import json
from glob import glob
from typing import Any
from typing import NewType

def np_encoder(object):
    if isinstance(object, np.generic):
        return object.item()


DictsPathType = NewType("DictsPath", str)


def load_file_json(path: DictsPathType):
    with open(path, "r") as f:
        return json.load(f)


def dump_file_json(path: DictsPathType, var: Any):
    with open(path, "w") as f:
        return json.dump(var, f, indent=4, default=np_encoder)


class LoadDicts:
    def __init__(self, dict_path: DictsPathType = "./data"):
        Dicts_glob = glob(f"{dict_path}/*.json")
        self.List = []
        self.Dict = {}
        for path_json in Dicts_glob:
            name = path_json.split("/")[-1].replace(".json", "")
            self.List.append(name)
            self.Dict[name] = load_file_json(path_json)
            setattr(self, name, self.Dict[name])

    def __repr__(self) -> str:
        return "LoadDicts: {}".format(", ".join(self.List))

# %%
# Run this cell before close.
# %watermark -d --iversion -b -r -g -m -v
# !cat /proc/cpuinfo |grep 'model name'|head -n 1 |sed -e 's/model\ name/CPU/'
# !free -h |cut -d'i' -f1  |grep -v total
# Out:
# Python implementation: CPython
# Python version       : 3.10.5
# IPython version      : 8.4.0
#
# Compiler    : GCC 10.2.1 20210110
# OS          : Linux
# Release     : 4.14.285-215.501.amzn2.x86_64
# Machine     : x86_64
# Processor   :
# CPU cores   : 4
# Architecture: 64bit
#
# Git hash: bcc395921b05b82fc8664b049faa785c4936800f
#
# Git repo: https://github.com/ysraell/random-forest-mc.git
#
# Git branch: dev
#
# re     : 2.2.1
# json   : 2.0.9
# sys    : 3.10.5 (main, Jul 12 2022, 11:32:11) [GCC 10.2.1 20210110]
# pandas : 1.4.3
# numpy  : 1.23.1
# logging: 0.5.1.2
#
# CPU	: Intel(R) Xeon(R) CPU E5-2686 v4 @ 2.30GHz
# Mem:            15G
# Swap:             0B          0B          0B

# %%
dataset_path_list = glob('/work/tmp/datasets/*.csv')
dataset_path_list
# Out:
# ['/work/tmp/datasets/creditcard.csv',
#  '/work/tmp/datasets/creditcard_trans_float.csv',
#  '/work/tmp/datasets/creditcard_trans_int.csv',
#  '/work/tmp/datasets/iris.csv',
#  '/work/tmp/datasets/titanic.csv']

# %%
dataset_dict = {
    'titanic' : {
        'ds_cols' : ['Pclass', 'Sex', 'Age', 'SibSp', 'Fare', 'Embarked'],
        'target_col' : 'Survived',
        'csv_path' : '/work/tmp/datasets/titanic.csv'
    },
    'iris': {
        'ds_cols' : ['sepal.length', 'sepal.width', 'petal.length', 'petal.width'],
        'target_col' : 'variety',
        'csv_path' : '/work/tmp/datasets/iris.csv'
    },
    'creditcard': {
        'ds_cols' : ['V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
       'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
       'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount'],
        'target_col' : 'Class',
        'csv_path' : '/work/tmp/datasets/creditcard.csv'
    },
    'creditcard_trans_int': {
        'ds_cols' : ['V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
       'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
       'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount'],
        'target_col' : 'Class',
        'csv_path' : '/work/tmp/datasets/creditcard_trans_int.csv'
    },
    'creditcard_trans_float': {
        'ds_cols' : ['V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
       'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
       'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount'],
        'target_col' : 'Class',
        'csv_path' : '/work/tmp/datasets/creditcard_trans_float.csv'
    }
}

# %%
ds_name = 'titanic'
md(f'# {ds_name}')
params = dataset_dict[ds_name]

dataset = pd.read_csv(params['csv_path'])[params['ds_cols']+[params['target_col']]].dropna().reset_index(drop=True)
dataset['Age'] = dataset['Age'].astype(np.uint8)
dataset['SibSp'] = dataset['SibSp'].astype(np.uint8)
dataset['Pclass'] = dataset['Pclass'].astype(str)
dataset['Fare'] = dataset['Fare'].astype(np.uint32)
cls = RandomForestMC(
    n_trees=8,
    target_col = params['target_col'],
    max_discard_trees = 4
)
cls.process_dataset(dataset)
cls.fit()
y_test = dataset[params['target_col']].to_list()
y_pred = cls.testForest(dataset)
accuracy_hard = "{:.2f}\%".format(100*sum([v == p for v, p in zip(y_test, y_pred)]) / len(y_pred))
cls.soft_voting=True
y_pred = cls.testForest(dataset)
accuracy_soft = "{:.2f}\%".format(100*sum([v == p for v, p in zip(y_test, y_pred)]) / len(y_pred))
md('## Accuracy:') 
md(f'## &nbsp;&nbsp;&nbsp; {accuracy_hard} (hard-voting)')
md(f'## &nbsp;&nbsp;&nbsp; {accuracy_soft} (soft-voting)')
# Out:
# # titanic
# Planting the forest: 100%|██████████| 8/8 [00:02<00:00,  3.90it/s]
# ## Accuracy:
# ## &nbsp;&nbsp;&nbsp; 77.25\% (hard-voting)
# ## &nbsp;&nbsp;&nbsp; 77.25\% (soft-voting)

# %%
model_dict = cls.model2dict()

# %%
model_dict
# Out:
# {'batch_train_pclass': 10,
#  'batch_val_pclass': 10,
#  '_N': 20,
#  'min_feature': 2,
#  'max_feature': 6,
#  'th_start': 0.9,
#  'delta_th': 0.1,
#  'max_discard_trees': 4,
#  'n_trees': 8,
#  'class_vals': ['0', '1'],
#  'survived_scores': [0.6, 0.85, 0.8, 0.7, 0.75, 0.7, 0.55, 0.8],
#  'version': '0.4.0-alpha',
#  'numeric_cols': ['Age', 'SibSp', 'Fare'],
#  'feature_cols': ['Pclass', 'Sex', 'Age', 'SibSp', 'Fare', 'Embarked'],
#  'type_of_cols': {'Age': 'numeric',
#   'SibSp': 'numeric',
#   'Fare': 'numeric',
#   'Sex': 'categorical',
#   'Embarked': 'categorical',
#   'Pclass': 'categorical'},
#  'target_col': 'Survived',
#  'Forest': [{'data': {'Sex': {'split': {'feat_type': 'categorical',
#       'split_val': 'male',
#       '>=': {'Embarked': {'split': {'feat_type': 'categorical',
#          'split_val': 'S',
#          '>=': {'Pclass': {'split': {'feat_type': 'categorical',
#             'split_val': '3',
#             '>=': {'SibSp': {'split': {'feat_type': 'numeric',
#                'split_val': 0,
#                '>=': {'Age': {'split': {'feat_type': 'numeric',
#                   'split_val': 9,
#                   '>=': {'leaf': {'0': 1.0}},
#                   '<': {'Sex': {'split': {'feat_type': 'categorical',
#                      'split_val': 'male',
#                      '>=': {'leaf': {'1': 1.0}},
#                      '<': {'leaf': {'0': 1.0}}}}}}}},
#                '<': {'Age': {'split': {'feat_type': 'numeric',
#                   'split_val': 20,
#                   '>=': {'leaf': {'0': 1.0}},
#                   '<': {'Sex': {'split': {'feat_type': 'categorical',
#                      'split_val': 'male',
#                      '>=': {'leaf': {'1': 1.0}},
#                      '<': {'leaf': {'0': 1.0}}}}}}}}}}},
#             '<': {'SibSp': {'split': {'feat_type': 'numeric',
#                'split_val': 3,
#                '>=': {'leaf': {'0': 1.0}},
#                '<': {'leaf': {'1': 1.0}}}}}}}},
#          '<': {'Pclass': {'split': {'feat_type': 'categorical',
#             'split_val': '3',
#             '>=': {'leaf': {'0': 1.0}},
#             '<': {'leaf': {'1': 1.0}}}}}}}},
#       '<': {'Embarked': {'split': {'feat_type': 'categorical',
#          'split_val': 'S',
#          '>=': {'Pclass': {'split': {'feat_type': 'categorical',
#             'split_val': '2',
#             '>=': {'leaf': {'1': 1.0}},
#             '<': {'SibSp': {'split': {'feat_type': 'numeric',
#                'split_val': 0,
#                '>=': {'leaf': {'1': 1.0}},
#                '<': {'Age': {'split': {'feat_type': 'numeric',
#                   'split_val': 28,
#                   '>=': {'leaf': {'0': 1.0}},
#                   '<': {'leaf': {'1': 1.0}}}}}}}}}}},
#          '<': {'leaf': {'1': 1.0}}}}}}}},
#    'class_vals': ['0', '1'],
#    'survived_score': 0.6,
#    'features': ['Pclass', 'Sex', 'Age', 'SibSp', 'Fare', 'Embarked'],
#    'used_features': ['Sex', 'SibSp', 'Embarked', 'Pclass', 'Age'],
#    'module_version': '0.4.0-alpha'},
#   {'data': {'Sex': {'split': {'feat_type': 'categorical',
#       'split_val': 'male',
#       '>=': {'Age': {'split': {'feat_type': 'numeric',
#          'split_val': 33,
#          '>=': {'Age': {'split': {'feat_type': 'numeric',
#             'split_val': 44,
#             '>=': {'Age': {'split': {'feat_type': 'numeric',
#                'split_val': 52,
#                '>=': {'Age': {'split': {'feat_type': 'numeric',
#                   'split_val': 54,
#                   '>=': {'leaf': {'0': 1.0}},
#                   '<': {'leaf': {'1': 1.0}}}}},
#                '<': {'Sex': {'split': {'feat_type': 'categorical',
#                   'split_val': 'male',
#                   '>=': {'leaf': {'1': 1.0}},
#                   '<': {'leaf': {'0': 1.0}}}}}}}},
#             '<': {'Age': {'split': {'feat_type': 'numeric',
#                'split_val': 35,
#                '>=': {'Age': {'split': {'feat_type': 'numeric',
#                   'split_val': 36,
#                   '>=': {'leaf': {'0': 1.0}},
#                   '<': {'leaf': {'1': 1.0}}}}},
#                '<': {'leaf': {'0': 1.0}}}}}}}},
#          '<': {'Age': {'split': {'feat_type': 'numeric',
#             'split_val': 24,
#             '>=': {'Age': {'split': {'feat_type': 'numeric',
#                'split_val': 26,
#                '>=': {'Age': {'split': {'feat_type': 'numeric',
#                   'split_val': 31,
#                   '>=': {'Sex': {'split': {'feat_type': 'categorical',
#                      'split_val': 'male',
#                      '>=': {'leaf': {'1': 1.0}},
#                      '<': {'leaf': {'0': 1.0}}}}},
#                   '<': {'leaf': {'0': 1.0}}}}},
#                '<': {'Age': {'split': {'feat_type': 'numeric',
#                   'split_val': 24,
#                   '>=': {'leaf': {'1': 1.0}},
#                   '<': {'Sex': {'split': {'feat_type': 'categorical',
#                      'split_val': 'male',
#                      '>=': {'leaf': {'1': 1.0}},
#                      '<': {'leaf': {'0': 1.0}}}}}}}}}}},
#             '<': {'Sex': {'split': {'feat_type': 'categorical',
#                'split_val': 'male',
#                '>=': {'leaf': {'1': 1.0}},
#                '<': {'leaf': {'0': 1.0}}}}}}}}}}},
#       '<': {'leaf': {'1': 1.0}}}}},
#    'class_vals': ['0', '1'],
#    'survived_score': 0.85,
#    'features': ['Pclass', 'Sex', 'Age', 'SibSp', 'Fare', 'Embarked'],
#    'used_features': ['Age', 'Sex'],
#    'module_version': '0.4.0-alpha'},
#   {'data': {'Embarked': {'split': {'feat_type': 'categorical',
#       'split_val': 'S',
#       '>=': {'Age': {'split': {'feat_type': 'numeric',
#          'split_val': 30,
#          '>=': {'SibSp': {'split': {'feat_type': 'numeric',
#             'split_val': 1,
#             '>=': {'Age': {'split': {'feat_type': 'numeric',
#                'split_val': 37,
#                '>=': {'SibSp': {'split': {'feat_type': 'numeric',
#                   'split_val': 1,
#                   '>=': {'Embarked': {'split': {'feat_type': 'categorical',
#                      'split_val': 'S',
#                      '>=': {'leaf': {'1': 1.0}},
#                      '<': {'leaf': {'0': 1.0}}}}},
#                   '<': {'Embarked': {'split': {'feat_type': 'categorical',
#                      'split_val': 'S',
#                      '>=': {'leaf': {'1': 1.0}},
#                      '<': {'leaf': {'0': 1.0}}}}}}}},
#                '<': {'leaf': {'1': 1.0}}}}},
#             '<': {'leaf': {'1': 1.0}}}}},
#          '<': {'leaf': {'0': 1.0}}}}},
#       '<': {'Age': {'split': {'feat_type': 'numeric',
#          'split_val': 30,
#          '>=': {'SibSp': {'split': {'feat_type': 'numeric',
#             'split_val': 0,
#             '>=': {'leaf': {'1': 1.0}},
#             '<': {'Embarked': {'split': {'feat_type': 'categorical',
#                'split_val': 'Q',
#                '>=': {'leaf': {'0': 1.0}},
#                '<': {'leaf': {'1': 1.0}}}}}}}},
#          '<': {'leaf': {'1': 1.0}}}}}}}},
#    'class_vals': ['0', '1'],
#    'survived_score': 0.8,
#    'features': ['Pclass', 'Sex', 'Age', 'SibSp', 'Fare', 'Embarked'],
#    'used_features': ['Embarked', 'Age', 'SibSp'],
#    'module_version': '0.4.0-alpha'},
#   {'data': {'SibSp': {'split': {'feat_type': 'numeric',
#       'split_val': 0,
#       '>=': {'Fare': {'split': {'feat_type': 'numeric',
#          'split_val': 14,
#          '>=': {'Age': {'split': {'feat_type': 'numeric',
#             'split_val': 26,
#             '>=': {'Sex': {'split': {'feat_type': 'categorical',
#                'split_val': 'female',
#                '>=': {'Embarked': {'split': {'feat_type': 'categorical',
#                   'split_val': 'S',
#                   '>=': {'leaf': {'1': 1.0}},
#                   '<': {'leaf': {'0': 1.0}}}}},
#                '<': {'leaf': {'0': 1.0}}}}},
#             '<': {'leaf': {'1': 1.0}}}}},
#          '<': {'Age': {'split': {'feat_type': 'numeric',
#             'split_val': 17,
#             '>=': {'Embarked': {'split': {'feat_type': 'categorical',
#                'split_val': 'C',
#                '>=': {'leaf': {'0': 1.0}},
#                '<': {'SibSp': {'split': {'feat_type': 'numeric',
#                   'split_val': 1,
#                   '>=': {'leaf': {'1': 1.0}},
#                   '<': {'leaf': {'0': 1.0}}}}}}}},
#             '<': {'leaf': {'1': 1.0}}}}}}}},
#       '<': {'Fare': {'split': {'feat_type': 'numeric',
#          'split_val': 11,
#          '>=': {'Age': {'split': {'feat_type': 'numeric',
#             'split_val': 38,
#             '>=': {'Sex': {'split': {'feat_type': 'categorical',
#                'split_val': 'female',
#                '>=': {'leaf': {'1': 1.0}},
#                '<': {'Embarked': {'split': {'feat_type': 'categorical',
#                   'split_val': 'S',
#                   '>=': {'leaf': {'0': 1.0}},
#                   '<': {'leaf': {'1': 1.0}}}}}}}},
#             '<': {'Sex': {'split': {'feat_type': 'categorical',
#                'split_val': 'female',
#                '>=': {'leaf': {'1': 1.0}},
#                '<': {'Embarked': {'split': {'feat_type': 'categorical',
#                   'split_val': 'S',
#                   '>=': {'leaf': {'1': 1.0}},
#                   '<': {'leaf': {'0': 1.0}}}}}}}}}}},
#          '<': {'Age': {'split': {'feat_type': 'numeric',
#             'split_val': 28,
#             '>=': {'leaf': {'0': 1.0}},
#             '<': {'Sex': {'split': {'feat_type': 'categorical',
#                'split_val': 'male',
#                '>=': {'leaf': {'0': 1.0}},
#                '<': {'leaf': {'1': 1.0}}}}}}}}}}}}}},
#    'class_vals': ['0', '1'],
#    'survived_score': 0.7,
#    'features': ['Pclass', 'Sex', 'Age', 'SibSp', 'Fare', 'Embarked'],
#    'used_features': ['Sex', 'SibSp', 'Embarked', 'Fare', 'Age'],
#    'module_version': '0.4.0-alpha'},
#   {'data': {'Sex': {'split': {'feat_type': 'categorical',
#       'split_val': 'female',
#       '>=': {'SibSp': {'split': {'feat_type': 'numeric',
#          'split_val': 0,
#          '>=': {'Fare': {'split': {'feat_type': 'numeric',
#             'split_val': 34,
#             '>=': {'Pclass': {'split': {'feat_type': 'categorical',
#                'split_val': '1',
#                '>=': {'leaf': {'1': 1.0}},
#                '<': {'leaf': {'0': 1.0}}}}},
#             '<': {'Pclass': {'split': {'feat_type': 'categorical',
#                'split_val': '3',
#                '>=': {'leaf': {'0': 1.0}},
#                '<': {'leaf': {'1': 1.0}}}}}}}},
#          '<': {'leaf': {'1': 1.0}}}}},
#       '<': {'SibSp': {'split': {'feat_type': 'numeric',
#          'split_val': 0,
#          '>=': {'leaf': {'0': 1.0}},
#          '<': {'Fare': {'split': {'feat_type': 'numeric',
#             'split_val': 10,
#             '>=': {'Pclass': {'split': {'feat_type': 'categorical',
#                'split_val': '2',
#                '>=': {'Fare': {'split': {'feat_type': 'numeric',
#                   'split_val': 10,
#                   '>=': {'leaf': {'0': 1.0}},
#                   '<': {'leaf': {'0': 0.6666666666666666,
#                     '1': 0.3333333333333333}}}}},
#                '<': {'leaf': {'1': 1.0}}}}},
#             '<': {'leaf': {'0': 1.0}}}}}}}}}}},
#    'class_vals': ['0', '1'],
#    'survived_score': 0.75,
#    'features': ['Pclass', 'Sex', 'Age', 'SibSp', 'Fare', 'Embarked'],
#    'used_features': ['Fare', 'Pclass', 'SibSp', 'Sex'],
#    'module_version': '0.4.0-alpha'},
#   {'data': {'Pclass': {'split': {'feat_type': 'categorical',
#       'split_val': '3',
#       '>=': {'Age': {'split': {'feat_type': 'numeric',
#          'split_val': 24,
#          '>=': {'leaf': {'0': 1.0}},
#          '<': {'Sex': {'split': {'feat_type': 'categorical',
#             'split_val': 'female',
#             '>=': {'leaf': {'1': 1.0}},
#             '<': {'SibSp': {'split': {'feat_type': 'numeric',
#                'split_val': 4,
#                '>=': {'leaf': {'0': 1.0}},
#                '<': {'leaf': {'1': 1.0}}}}}}}}}}},
#       '<': {'Age': {'split': {'feat_type': 'numeric',
#          'split_val': 33,
#          '>=': {'Sex': {'split': {'feat_type': 'categorical',
#             'split_val': 'female',
#             '>=': {'leaf': {'1': 1.0}},
#             '<': {'leaf': {'0': 1.0}}}}},
#          '<': {'Sex': {'split': {'feat_type': 'categorical',
#             'split_val': 'female',
#             '>=': {'leaf': {'1': 1.0}},
#             '<': {'leaf': {'0': 1.0}}}}}}}}}}},
#    'class_vals': ['0', '1'],
#    'survived_score': 0.7,
#    'features': ['Pclass', 'Sex', 'Age', 'SibSp', 'Fare', 'Embarked'],
#    'used_features': ['Pclass', 'SibSp', 'Age', 'Sex'],
#    'module_version': '0.4.0-alpha'},
#   {'data': {'Fare': {'split': {'feat_type': 'numeric',
#       'split_val': 28,
#       '>=': {'Age': {'split': {'feat_type': 'numeric',
#          'split_val': 24,
#          '>=': {'Sex': {'split': {'feat_type': 'categorical',
#             'split_val': 'male',
#             '>=': {'leaf': {'0': 1.0}},
#             '<': {'leaf': {'1': 1.0}}}}},
#          '<': {'Pclass': {'split': {'feat_type': 'categorical',
#             'split_val': '1',
#             '>=': {'Sex': {'split': {'feat_type': 'categorical',
#                'split_val': 'female',
#                '>=': {'leaf': {'1': 1.0}},
#                '<': {'leaf': {'0': 1.0}}}}},
#             '<': {'Sex': {'split': {'feat_type': 'categorical',
#                'split_val': 'male',
#                '>=': {'leaf': {'1': 1.0}},
#                '<': {'leaf': {'0': 1.0}}}}}}}}}}},
#       '<': {'Age': {'split': {'feat_type': 'numeric',
#          'split_val': 29,
#          '>=': {'Pclass': {'split': {'feat_type': 'categorical',
#             'split_val': '3',
#             '>=': {'Sex': {'split': {'feat_type': 'categorical',
#                'split_val': 'female',
#                '>=': {'leaf': {'0': 1.0}},
#                '<': {'Fare': {'split': {'feat_type': 'numeric',
#                   'split_val': 9,
#                   '>=': {'leaf': {'1': 1.0}},
#                   '<': {'leaf': {'0': 1.0}}}}}}}},
#             '<': {'Sex': {'split': {'feat_type': 'categorical',
#                'split_val': 'male',
#                '>=': {'leaf': {'0': 1.0}},
#                '<': {'leaf': {'1': 1.0}}}}}}}},
#          '<': {'Pclass': {'split': {'feat_type': 'categorical',
#             'split_val': '2',
#             '>=': {'leaf': {'1': 1.0}},
#             '<': {'leaf': {'0': 1.0}}}}}}}}}}},
#    'class_vals': ['0', '1'],
#    'survived_score': 0.55,
#    'features': ['Pclass', 'Sex', 'Age', 'SibSp', 'Fare', 'Embarked'],
#    'used_features': ['Fare', 'Pclass', 'Age', 'Sex'],
#    'module_version': '0.4.0-alpha'},
#   {'data': {'Sex': {'split': {'feat_type': 'categorical',
#       'split_val': 'male',
#       '>=': {'Fare': {'split': {'feat_type': 'numeric',
#          'split_val': 9,
#          '>=': {'Pclass': {'split': {'feat_type': 'categorical',
#             'split_val': '3',
#             '>=': {'Age': {'split': {'feat_type': 'numeric',
#                'split_val': 16,
#                '>=': {'Sex': {'split': {'feat_type': 'categorical',
#                   'split_val': 'male',
#                   '>=': {'leaf': {'1': 1.0}},
#                   '<': {'leaf': {'0': 1.0}}}}},
#                '<': {'Sex': {'split': {'feat_type': 'categorical',
#                   'split_val': 'male',
#                   '>=': {'leaf': {'1': 1.0}},
#                   '<': {'leaf': {'0': 1.0}}}}}}}},
#             '<': {'Embarked': {'split': {'feat_type': 'categorical',
#                'split_val': 'C',
#                '>=': {'leaf': {'1': 1.0}},
#                '<': {'leaf': {'0': 1.0}}}}}}}},
#          '<': {'Embarked': {'split': {'feat_type': 'categorical',
#             'split_val': 'S',
#             '>=': {'Age': {'split': {'feat_type': 'numeric',
#                'split_val': 20,
#                '>=': {'leaf': {'0': 1.0}},
#                '<': {'leaf': {'1': 1.0}}}}},
#             '<': {'leaf': {'0': 1.0}}}}}}}},
#       '<': {'Fare': {'split': {'feat_type': 'numeric',
#          'split_val': 22,
#          '>=': {'Pclass': {'split': {'feat_type': 'categorical',
#             'split_val': '1',
#             '>=': {'leaf': {'1': 1.0}},
#             '<': {'Embarked': {'split': {'feat_type': 'categorical',
#                'split_val': 'S',
#                '>=': {'leaf': {'1': 1.0}},
#                '<': {'leaf': {'0': 1.0}}}}}}}},
#          '<': {'Embarked': {'split': {'feat_type': 'categorical',
#             'split_val': 'S',
#             '>=': {'leaf': {'1': 1.0}},
#             '<': {'Age': {'split': {'feat_type': 'numeric',
#                'split_val': 30,
#                '>=': {'leaf': {'0': 1.0}},
#                '<': {'leaf': {'1': 1.0}}}}}}}}}}}}}},
#    'class_vals': ['0', '1'],
#    'survived_score': 0.8,
#    'features': ['Pclass', 'Sex', 'Age', 'SibSp', 'Fare', 'Embarked'],
#    'used_features': ['Fare', 'Sex', 'Embarked', 'Pclass', 'Age'],
#    'module_version': '0.4.0-alpha'}]}

# %%
# !ls /work/tmp/cls_rfmc_titanic.json
# !rm /work/tmp/cls_rfmc_titanic.json
# Out:
# /work/tmp/cls_rfmc_titanic.json

# %%
model_dict = cls.model2dict()
model_path = '/work/tmp/cls_rfmc_titanic.json'
dump_file_json(model_path, model_dict)

# %%
modeldict = load_file_json(model_path)
modeldict
# Out:
# {'batch_train_pclass': 10,
#  'batch_val_pclass': 10,
#  '_N': 20,
#  'min_feature': 2,
#  'max_feature': 6,
#  'th_start': 0.9,
#  'delta_th': 0.1,
#  'max_discard_trees': 4,
#  'n_trees': 8,
#  'class_vals': ['0', '1'],
#  'survived_scores': [0.6, 0.85, 0.8, 0.7, 0.75, 0.7, 0.55, 0.8],
#  'version': '0.4.0-alpha',
#  'numeric_cols': ['Age', 'SibSp', 'Fare'],
#  'feature_cols': ['Pclass', 'Sex', 'Age', 'SibSp', 'Fare', 'Embarked'],
#  'type_of_cols': {'Age': 'numeric',
#   'SibSp': 'numeric',
#   'Fare': 'numeric',
#   'Sex': 'categorical',
#   'Embarked': 'categorical',
#   'Pclass': 'categorical'},
#  'target_col': 'Survived',
#  'Forest': [{'data': {'Sex': {'split': {'feat_type': 'categorical',
#       'split_val': 'male',
#       '>=': {'Embarked': {'split': {'feat_type': 'categorical',
#          'split_val': 'S',
#          '>=': {'Pclass': {'split': {'feat_type': 'categorical',
#             'split_val': '3',
#             '>=': {'SibSp': {'split': {'feat_type': 'numeric',
#                'split_val': 0,
#                '>=': {'Age': {'split': {'feat_type': 'numeric',
#                   'split_val': 9,
#                   '>=': {'leaf': {'0': 1.0}},
#                   '<': {'Sex': {'split': {'feat_type': 'categorical',
#                      'split_val': 'male',
#                      '>=': {'leaf': {'1': 1.0}},
#                      '<': {'leaf': {'0': 1.0}}}}}}}},
#                '<': {'Age': {'split': {'feat_type': 'numeric',
#                   'split_val': 20,
#                   '>=': {'leaf': {'0': 1.0}},
#                   '<': {'Sex': {'split': {'feat_type': 'categorical',
#                      'split_val': 'male',
#                      '>=': {'leaf': {'1': 1.0}},
#                      '<': {'leaf': {'0': 1.0}}}}}}}}}}},
#             '<': {'SibSp': {'split': {'feat_type': 'numeric',
#                'split_val': 3,
#                '>=': {'leaf': {'0': 1.0}},
#                '<': {'leaf': {'1': 1.0}}}}}}}},
#          '<': {'Pclass': {'split': {'feat_type': 'categorical',
#             'split_val': '3',
#             '>=': {'leaf': {'0': 1.0}},
#             '<': {'leaf': {'1': 1.0}}}}}}}},
#       '<': {'Embarked': {'split': {'feat_type': 'categorical',
#          'split_val': 'S',
#          '>=': {'Pclass': {'split': {'feat_type': 'categorical',
#             'split_val': '2',
#             '>=': {'leaf': {'1': 1.0}},
#             '<': {'SibSp': {'split': {'feat_type': 'numeric',
#                'split_val': 0,
#                '>=': {'leaf': {'1': 1.0}},
#                '<': {'Age': {'split': {'feat_type': 'numeric',
#                   'split_val': 28,
#                   '>=': {'leaf': {'0': 1.0}},
#                   '<': {'leaf': {'1': 1.0}}}}}}}}}}},
#          '<': {'leaf': {'1': 1.0}}}}}}}},
#    'class_vals': ['0', '1'],
#    'survived_score': 0.6,
#    'features': ['Pclass', 'Sex', 'Age', 'SibSp', 'Fare', 'Embarked'],
#    'used_features': ['Sex', 'SibSp', 'Embarked', 'Pclass', 'Age'],
#    'module_version': '0.4.0-alpha'},
#   {'data': {'Sex': {'split': {'feat_type': 'categorical',
#       'split_val': 'male',
#       '>=': {'Age': {'split': {'feat_type': 'numeric',
#          'split_val': 33,
#          '>=': {'Age': {'split': {'feat_type': 'numeric',
#             'split_val': 44,
#             '>=': {'Age': {'split': {'feat_type': 'numeric',
#                'split_val': 52,
#                '>=': {'Age': {'split': {'feat_type': 'numeric',
#                   'split_val': 54,
#                   '>=': {'leaf': {'0': 1.0}},
#                   '<': {'leaf': {'1': 1.0}}}}},
#                '<': {'Sex': {'split': {'feat_type': 'categorical',
#                   'split_val': 'male',
#                   '>=': {'leaf': {'1': 1.0}},
#                   '<': {'leaf': {'0': 1.0}}}}}}}},
#             '<': {'Age': {'split': {'feat_type': 'numeric',
#                'split_val': 35,
#                '>=': {'Age': {'split': {'feat_type': 'numeric',
#                   'split_val': 36,
#                   '>=': {'leaf': {'0': 1.0}},
#                   '<': {'leaf': {'1': 1.0}}}}},
#                '<': {'leaf': {'0': 1.0}}}}}}}},
#          '<': {'Age': {'split': {'feat_type': 'numeric',
#             'split_val': 24,
#             '>=': {'Age': {'split': {'feat_type': 'numeric',
#                'split_val': 26,
#                '>=': {'Age': {'split': {'feat_type': 'numeric',
#                   'split_val': 31,
#                   '>=': {'Sex': {'split': {'feat_type': 'categorical',
#                      'split_val': 'male',
#                      '>=': {'leaf': {'1': 1.0}},
#                      '<': {'leaf': {'0': 1.0}}}}},
#                   '<': {'leaf': {'0': 1.0}}}}},
#                '<': {'Age': {'split': {'feat_type': 'numeric',
#                   'split_val': 24,
#                   '>=': {'leaf': {'1': 1.0}},
#                   '<': {'Sex': {'split': {'feat_type': 'categorical',
#                      'split_val': 'male',
#                      '>=': {'leaf': {'1': 1.0}},
#                      '<': {'leaf': {'0': 1.0}}}}}}}}}}},
#             '<': {'Sex': {'split': {'feat_type': 'categorical',
#                'split_val': 'male',
#                '>=': {'leaf': {'1': 1.0}},
#                '<': {'leaf': {'0': 1.0}}}}}}}}}}},
#       '<': {'leaf': {'1': 1.0}}}}},
#    'class_vals': ['0', '1'],
#    'survived_score': 0.85,
#    'features': ['Pclass', 'Sex', 'Age', 'SibSp', 'Fare', 'Embarked'],
#    'used_features': ['Age', 'Sex'],
#    'module_version': '0.4.0-alpha'},
#   {'data': {'Embarked': {'split': {'feat_type': 'categorical',
#       'split_val': 'S',
#       '>=': {'Age': {'split': {'feat_type': 'numeric',
#          'split_val': 30,
#          '>=': {'SibSp': {'split': {'feat_type': 'numeric',
#             'split_val': 1,
#             '>=': {'Age': {'split': {'feat_type': 'numeric',
#                'split_val': 37,
#                '>=': {'SibSp': {'split': {'feat_type': 'numeric',
#                   'split_val': 1,
#                   '>=': {'Embarked': {'split': {'feat_type': 'categorical',
#                      'split_val': 'S',
#                      '>=': {'leaf': {'1': 1.0}},
#                      '<': {'leaf': {'0': 1.0}}}}},
#                   '<': {'Embarked': {'split': {'feat_type': 'categorical',
#                      'split_val': 'S',
#                      '>=': {'leaf': {'1': 1.0}},
#                      '<': {'leaf': {'0': 1.0}}}}}}}},
#                '<': {'leaf': {'1': 1.0}}}}},
#             '<': {'leaf': {'1': 1.0}}}}},
#          '<': {'leaf': {'0': 1.0}}}}},
#       '<': {'Age': {'split': {'feat_type': 'numeric',
#          'split_val': 30,
#          '>=': {'SibSp': {'split': {'feat_type': 'numeric',
#             'split_val': 0,
#             '>=': {'leaf': {'1': 1.0}},
#             '<': {'Embarked': {'split': {'feat_type': 'categorical',
#                'split_val': 'Q',
#                '>=': {'leaf': {'0': 1.0}},
#                '<': {'leaf': {'1': 1.0}}}}}}}},
#          '<': {'leaf': {'1': 1.0}}}}}}}},
#    'class_vals': ['0', '1'],
#    'survived_score': 0.8,
#    'features': ['Pclass', 'Sex', 'Age', 'SibSp', 'Fare', 'Embarked'],
#    'used_features': ['Embarked', 'Age', 'SibSp'],
#    'module_version': '0.4.0-alpha'},
#   {'data': {'SibSp': {'split': {'feat_type': 'numeric',
#       'split_val': 0,
#       '>=': {'Fare': {'split': {'feat_type': 'numeric',
#          'split_val': 14,
#          '>=': {'Age': {'split': {'feat_type': 'numeric',
#             'split_val': 26,
#             '>=': {'Sex': {'split': {'feat_type': 'categorical',
#                'split_val': 'female',
#                '>=': {'Embarked': {'split': {'feat_type': 'categorical',
#                   'split_val': 'S',
#                   '>=': {'leaf': {'1': 1.0}},
#                   '<': {'leaf': {'0': 1.0}}}}},
#                '<': {'leaf': {'0': 1.0}}}}},
#             '<': {'leaf': {'1': 1.0}}}}},
#          '<': {'Age': {'split': {'feat_type': 'numeric',
#             'split_val': 17,
#             '>=': {'Embarked': {'split': {'feat_type': 'categorical',
#                'split_val': 'C',
#                '>=': {'leaf': {'0': 1.0}},
#                '<': {'SibSp': {'split': {'feat_type': 'numeric',
#                   'split_val': 1,
#                   '>=': {'leaf': {'1': 1.0}},
#                   '<': {'leaf': {'0': 1.0}}}}}}}},
#             '<': {'leaf': {'1': 1.0}}}}}}}},
#       '<': {'Fare': {'split': {'feat_type': 'numeric',
#          'split_val': 11,
#          '>=': {'Age': {'split': {'feat_type': 'numeric',
#             'split_val': 38,
#             '>=': {'Sex': {'split': {'feat_type': 'categorical',
#                'split_val': 'female',
#                '>=': {'leaf': {'1': 1.0}},
#                '<': {'Embarked': {'split': {'feat_type': 'categorical',
#                   'split_val': 'S',
#                   '>=': {'leaf': {'0': 1.0}},
#                   '<': {'leaf': {'1': 1.0}}}}}}}},
#             '<': {'Sex': {'split': {'feat_type': 'categorical',
#                'split_val': 'female',
#                '>=': {'leaf': {'1': 1.0}},
#                '<': {'Embarked': {'split': {'feat_type': 'categorical',
#                   'split_val': 'S',
#                   '>=': {'leaf': {'1': 1.0}},
#                   '<': {'leaf': {'0': 1.0}}}}}}}}}}},
#          '<': {'Age': {'split': {'feat_type': 'numeric',
#             'split_val': 28,
#             '>=': {'leaf': {'0': 1.0}},
#             '<': {'Sex': {'split': {'feat_type': 'categorical',
#                'split_val': 'male',
#                '>=': {'leaf': {'0': 1.0}},
#                '<': {'leaf': {'1': 1.0}}}}}}}}}}}}}},
#    'class_vals': ['0', '1'],
#    'survived_score': 0.7,
#    'features': ['Pclass', 'Sex', 'Age', 'SibSp', 'Fare', 'Embarked'],
#    'used_features': ['Sex', 'SibSp', 'Embarked', 'Fare', 'Age'],
#    'module_version': '0.4.0-alpha'},
#   {'data': {'Sex': {'split': {'feat_type': 'categorical',
#       'split_val': 'female',
#       '>=': {'SibSp': {'split': {'feat_type': 'numeric',
#          'split_val': 0,
#          '>=': {'Fare': {'split': {'feat_type': 'numeric',
#             'split_val': 34,
#             '>=': {'Pclass': {'split': {'feat_type': 'categorical',
#                'split_val': '1',
#                '>=': {'leaf': {'1': 1.0}},
#                '<': {'leaf': {'0': 1.0}}}}},
#             '<': {'Pclass': {'split': {'feat_type': 'categorical',
#                'split_val': '3',
#                '>=': {'leaf': {'0': 1.0}},
#                '<': {'leaf': {'1': 1.0}}}}}}}},
#          '<': {'leaf': {'1': 1.0}}}}},
#       '<': {'SibSp': {'split': {'feat_type': 'numeric',
#          'split_val': 0,
#          '>=': {'leaf': {'0': 1.0}},
#          '<': {'Fare': {'split': {'feat_type': 'numeric',
#             'split_val': 10,
#             '>=': {'Pclass': {'split': {'feat_type': 'categorical',
#                'split_val': '2',
#                '>=': {'Fare': {'split': {'feat_type': 'numeric',
#                   'split_val': 10,
#                   '>=': {'leaf': {'0': 1.0}},
#                   '<': {'leaf': {'0': 0.6666666666666666,
#                     '1': 0.3333333333333333}}}}},
#                '<': {'leaf': {'1': 1.0}}}}},
#             '<': {'leaf': {'0': 1.0}}}}}}}}}}},
#    'class_vals': ['0', '1'],
#    'survived_score': 0.75,
#    'features': ['Pclass', 'Sex', 'Age', 'SibSp', 'Fare', 'Embarked'],
#    'used_features': ['Fare', 'Pclass', 'SibSp', 'Sex'],
#    'module_version': '0.4.0-alpha'},
#   {'data': {'Pclass': {'split': {'feat_type': 'categorical',
#       'split_val': '3',
#       '>=': {'Age': {'split': {'feat_type': 'numeric',
#          'split_val': 24,
#          '>=': {'leaf': {'0': 1.0}},
#          '<': {'Sex': {'split': {'feat_type': 'categorical',
#             'split_val': 'female',
#             '>=': {'leaf': {'1': 1.0}},
#             '<': {'SibSp': {'split': {'feat_type': 'numeric',
#                'split_val': 4,
#                '>=': {'leaf': {'0': 1.0}},
#                '<': {'leaf': {'1': 1.0}}}}}}}}}}},
#       '<': {'Age': {'split': {'feat_type': 'numeric',
#          'split_val': 33,
#          '>=': {'Sex': {'split': {'feat_type': 'categorical',
#             'split_val': 'female',
#             '>=': {'leaf': {'1': 1.0}},
#             '<': {'leaf': {'0': 1.0}}}}},
#          '<': {'Sex': {'split': {'feat_type': 'categorical',
#             'split_val': 'female',
#             '>=': {'leaf': {'1': 1.0}},
#             '<': {'leaf': {'0': 1.0}}}}}}}}}}},
#    'class_vals': ['0', '1'],
#    'survived_score': 0.7,
#    'features': ['Pclass', 'Sex', 'Age', 'SibSp', 'Fare', 'Embarked'],
#    'used_features': ['Pclass', 'SibSp', 'Age', 'Sex'],
#    'module_version': '0.4.0-alpha'},
#   {'data': {'Fare': {'split': {'feat_type': 'numeric',
#       'split_val': 28,
#       '>=': {'Age': {'split': {'feat_type': 'numeric',
#          'split_val': 24,
#          '>=': {'Sex': {'split': {'feat_type': 'categorical',
#             'split_val': 'male',
#             '>=': {'leaf': {'0': 1.0}},
#             '<': {'leaf': {'1': 1.0}}}}},
#          '<': {'Pclass': {'split': {'feat_type': 'categorical',
#             'split_val': '1',
#             '>=': {'Sex': {'split': {'feat_type': 'categorical',
#                'split_val': 'female',
#                '>=': {'leaf': {'1': 1.0}},
#                '<': {'leaf': {'0': 1.0}}}}},
#             '<': {'Sex': {'split': {'feat_type': 'categorical',
#                'split_val': 'male',
#                '>=': {'leaf': {'1': 1.0}},
#                '<': {'leaf': {'0': 1.0}}}}}}}}}}},
#       '<': {'Age': {'split': {'feat_type': 'numeric',
#          'split_val': 29,
#          '>=': {'Pclass': {'split': {'feat_type': 'categorical',
#             'split_val': '3',
#             '>=': {'Sex': {'split': {'feat_type': 'categorical',
#                'split_val': 'female',
#                '>=': {'leaf': {'0': 1.0}},
#                '<': {'Fare': {'split': {'feat_type': 'numeric',
#                   'split_val': 9,
#                   '>=': {'leaf': {'1': 1.0}},
#                   '<': {'leaf': {'0': 1.0}}}}}}}},
#             '<': {'Sex': {'split': {'feat_type': 'categorical',
#                'split_val': 'male',
#                '>=': {'leaf': {'0': 1.0}},
#                '<': {'leaf': {'1': 1.0}}}}}}}},
#          '<': {'Pclass': {'split': {'feat_type': 'categorical',
#             'split_val': '2',
#             '>=': {'leaf': {'1': 1.0}},
#             '<': {'leaf': {'0': 1.0}}}}}}}}}}},
#    'class_vals': ['0', '1'],
#    'survived_score': 0.55,
#    'features': ['Pclass', 'Sex', 'Age', 'SibSp', 'Fare', 'Embarked'],
#    'used_features': ['Fare', 'Pclass', 'Age', 'Sex'],
#    'module_version': '0.4.0-alpha'},
#   {'data': {'Sex': {'split': {'feat_type': 'categorical',
#       'split_val': 'male',
#       '>=': {'Fare': {'split': {'feat_type': 'numeric',
#          'split_val': 9,
#          '>=': {'Pclass': {'split': {'feat_type': 'categorical',
#             'split_val': '3',
#             '>=': {'Age': {'split': {'feat_type': 'numeric',
#                'split_val': 16,
#                '>=': {'Sex': {'split': {'feat_type': 'categorical',
#                   'split_val': 'male',
#                   '>=': {'leaf': {'1': 1.0}},
#                   '<': {'leaf': {'0': 1.0}}}}},
#                '<': {'Sex': {'split': {'feat_type': 'categorical',
#                   'split_val': 'male',
#                   '>=': {'leaf': {'1': 1.0}},
#                   '<': {'leaf': {'0': 1.0}}}}}}}},
#             '<': {'Embarked': {'split': {'feat_type': 'categorical',
#                'split_val': 'C',
#                '>=': {'leaf': {'1': 1.0}},
#                '<': {'leaf': {'0': 1.0}}}}}}}},
#          '<': {'Embarked': {'split': {'feat_type': 'categorical',
#             'split_val': 'S',
#             '>=': {'Age': {'split': {'feat_type': 'numeric',
#                'split_val': 20,
#                '>=': {'leaf': {'0': 1.0}},
#                '<': {'leaf': {'1': 1.0}}}}},
#             '<': {'leaf': {'0': 1.0}}}}}}}},
#       '<': {'Fare': {'split': {'feat_type': 'numeric',
#          'split_val': 22,
#          '>=': {'Pclass': {'split': {'feat_type': 'categorical',
#             'split_val': '1',
#             '>=': {'leaf': {'1': 1.0}},
#             '<': {'Embarked': {'split': {'feat_type': 'categorical',
#                'split_val': 'S',
#                '>=': {'leaf': {'1': 1.0}},
#                '<': {'leaf': {'0': 1.0}}}}}}}},
#          '<': {'Embarked': {'split': {'feat_type': 'categorical',
#             'split_val': 'S',
#             '>=': {'leaf': {'1': 1.0}},
#             '<': {'Age': {'split': {'feat_type': 'numeric',
#                'split_val': 30,
#                '>=': {'leaf': {'0': 1.0}},
#                '<': {'leaf': {'1': 1.0}}}}}}}}}}}}}},
#    'class_vals': ['0', '1'],
#    'survived_score': 0.8,
#    'features': ['Pclass', 'Sex', 'Age', 'SibSp', 'Fare', 'Embarked'],
#    'used_features': ['Fare', 'Sex', 'Embarked', 'Pclass', 'Age'],
#    'module_version': '0.4.0-alpha'}]}

# %%
cls = RandomForestMC()
cls
# Out:
# RandomForestMC(len(Forest)=0,n_trees=16,model_version=0.4.0-alpha,module_version=0.4.0-alpha)

# %%
cls.data
# Out:
# []

# %%
cls.dict2model(modeldict)

# %%
cls.data
# Out:
# [DecisionTreeMC(survived_score=0.6,module_version=0.4.0-alpha),
#  DecisionTreeMC(survived_score=0.85,module_version=0.4.0-alpha),
#  DecisionTreeMC(survived_score=0.8,module_version=0.4.0-alpha),
#  DecisionTreeMC(survived_score=0.7,module_version=0.4.0-alpha),
#  DecisionTreeMC(survived_score=0.75,module_version=0.4.0-alpha),
#  DecisionTreeMC(survived_score=0.7,module_version=0.4.0-alpha),
#  DecisionTreeMC(survived_score=0.55,module_version=0.4.0-alpha),
#  DecisionTreeMC(survived_score=0.8,module_version=0.4.0-alpha)]

# %%
y_test = dataset[params['target_col']].to_list()
y_pred = cls.testForest(dataset)
accuracy_hard = "{:.2f}\%".format(100*sum([v == p for v, p in zip(y_test, y_pred)]) / len(y_pred))
cls.soft_voting=True
y_pred = cls.testForest(dataset)
accuracy_soft = "{:.2f}\%".format(100*sum([v == p for v, p in zip(y_test, y_pred)]) / len(y_pred))
md('## Accuracy:') 
md(f'## &nbsp;&nbsp;&nbsp; {accuracy_hard} (hard-voting)')
md(f'## &nbsp;&nbsp;&nbsp; {accuracy_soft} (soft-voting)')
# Out:
# ## Accuracy:
# ## &nbsp;&nbsp;&nbsp; 77.25\% (hard-voting)
# ## &nbsp;&nbsp;&nbsp; 77.25\% (soft-voting)
